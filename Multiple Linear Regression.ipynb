# %%
import pandas as pd

# %%
Startups=pd.read_csv("50_Startups.csv")

# %%
Startups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(Startups["R&D Spend"],Startups["Profit"],color="red")

# %%
plt.scatter(Startups["Administration"],Startups["Profit"],color="teal")

# %%
plt.scatter(Startups["Marketing Spend"],Startups["Profit"],color="black")

# %%
from sklearn.linear_model import LinearRegression

# %%
Reg1=LinearRegression()

# %%
x = Startups.iloc[:,0:3].values

# %%
x
# Out:
# array([[165349.2 , 136897.8 , 471784.1 ],
#        [162597.7 , 151377.59, 443898.53],
#        [153441.51, 101145.55, 407934.54],
#        [144372.41, 118671.85, 383199.62],
#        [142107.34,  91391.77, 366168.42],
#        [131876.9 ,  99814.71, 362861.36],
#        [134615.46, 147198.87, 127716.82],
#        [130298.13, 145530.06, 323876.68],
#        [120542.52, 148718.95, 311613.29],
#        [123334.88, 108679.17, 304981.62],
#        [101913.08, 110594.11, 229160.95],
#        [100671.96,  91790.61, 249744.55],
#        [ 93863.75, 127320.38, 249839.44],
#        [ 91992.39, 135495.07, 252664.93],
#        [119943.24, 156547.42, 256512.92],
#        [114523.61, 122616.84, 261776.23],
#        [ 78013.11, 121597.55, 264346.06],
#        [ 94657.16, 145077.58, 282574.31],
#        [ 91749.16, 114175.79, 294919.57],
#        [ 86419.7 , 153514.11,      0.  ],
#        [ 76253.86, 113867.3 , 298664.47],
#        [ 78389.47, 153773.43, 299737.29],
# ...

# %%
y=Startups.iloc[:,-1].values

# %%
y
# Out:
# array([192261.83, 191792.06, 191050.39, 182901.99, 166187.94, 156991.12,
#        156122.51, 155752.6 , 152211.77, 149759.96, 146121.95, 144259.4 ,
#        141585.52, 134307.35, 132602.65, 129917.04, 126992.93, 125370.37,
#        124266.9 , 122776.86, 118474.03, 111313.02, 110352.25, 108733.99,
#        108552.04, 107404.34, 105733.54, 105008.31, 103282.38, 101004.64,
#         99937.59,  97483.56,  97427.84,  96778.92,  96712.8 ,  96479.51,
#         90708.19,  89949.14,  81229.06,  81005.76,  78239.91,  77798.83,
#         71498.49,  69758.98,  65200.33,  64926.08,  49490.75,  42559.73,
#         35673.41,  14681.4 ])

# %%
Reg1.fit(x,y)
# Out:
# LinearRegression()

# %%
Reg1.predict(x)
# Out:
# array([192521.25289008, 189156.76823227, 182147.2790962 , 173696.70002553,
#        172139.51418327, 163580.7805712 , 158114.09666865, 160021.36304781,
#        151741.69969865, 154884.68410995, 135509.01636714, 135573.71296074,
#        129138.05418243, 127487.99166275, 149548.64633453, 146235.1599852 ,
#        116915.40540144, 130192.44720781, 129014.2268059 , 115635.21636716,
#        116639.6692309 , 117319.45164029, 114706.98171695, 109996.61522126,
#        113362.96611314, 102237.72506481, 110600.5753503 , 114408.07145684,
#        101660.02600497, 101794.98345176,  99452.37293606,  97687.85627575,
#         99001.32898549,  97915.00780465,  89039.27374116,  90511.59956753,
#         75286.17458546,  89619.5377079 ,  69697.43064804,  83729.01197692,
#         74815.95399105,  74802.55623866,  70620.41182056,  60167.03996335,
#         64611.3549157 ,  47650.64968691,  56166.20685261,  46490.58898335,
#         49171.38815763,  48215.1341113 ])

# %%
error = y - Reg1.predict(x);error
# Out:
# array([  -259.42289008,   2635.29176773,   8903.1109038 ,   9205.28997447,
#         -5951.57418327,  -6589.6605712 ,  -1991.58666865,  -4268.76304781,
#           470.07030135,  -5124.72410995,  10612.93363286,   8685.68703926,
#         12447.46581757,   6819.35833725, -16945.99633453, -16318.1199852 ,
#         10077.52459856,  -4822.07720781,  -4747.3268059 ,   7141.64363284,
#          1834.3607691 ,  -6006.43164029,  -4354.73171695,  -1262.62522126,
#         -4810.92611314,   5166.61493519,  -4867.0353503 ,  -9399.76145684,
#          1622.35399503,   -790.34345176,    485.21706394,   -204.29627575,
#         -1573.48898549,  -1136.08780465,   7673.52625884,   5967.91043247,
#         15422.01541454,    329.6022921 ,  11531.62935196,  -2723.25197692,
#          3423.95600895,   2996.27376134,    878.07817944,   9591.94003665,
#           588.9750843 ,  17275.43031309,  -6675.45685261,  -3930.85898335,
#        -13497.97815763, -33533.7341113 ])
